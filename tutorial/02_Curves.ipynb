# %% [markdown]
# # All about curves
#
# Some preliminaries...

# %%
import numpy as np
import matplotlib.pyplot as plt

import welly
welly.__version__

# %% [markdown]
# ## Load a well from LAS
#
# Use the `from_las()` method to load a well by passing a filename as a `str`.
#
# This is really just a wrapper for `lasio` but instantiates a `Header`, `Curve`s, etc.

# %%
from welly import Well

# %%
w = Well.from_las('data/P-129_out.LAS')
# Out:
# Only engine='normal' can read wrapped files

# %%
w.plot()
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:

# %% [markdown]
# Let's look at one log:

# %%
w.data['GR']
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:342: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if self.dtypes[0] == float:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:347: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rows += s.format(depth, value[0])
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:350: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rows += s.format(depth, value[0])
# Curve(mnemonic=GR, units=gAPI, start=1.0668, stop=1939.1376, step=0.1524, count=[12718])

# %% [markdown]
# ## Curves
#
# `w.data` is just a dictionary mapping mnemonic to Curve object.

# %%
w.data  # Just a dict of data objects.
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# {'CALI': Curve(mnemonic=CALI, units=in, start=1.0668, stop=1939.1376, step=0.1524, count=[12718]),
#  'HCAL': Curve(mnemonic=HCAL, units=in, start=1.0668, stop=1939.1376, step=0.1524, count=[2139]),
#  'PEF': Curve(mnemonic=PEF, units=, start=1.0668, stop=1939.1376, step=0.1524, count=[12718]),
#  'DT': Curve(mnemonic=DT, units=us/ft, start=1.0668, stop=1939.1376, step=0.1524, count=[10850]),
#  'DTS': Curve(mnemonic=DTS, units=us/ft, start=1.0668, stop=1939.1376, step=0.1524, count=[10850]),
#  'DPHI_SAN': Curve(mnemonic=DPHI_SAN, units=m3/m3, start=1.0668, stop=1939.1376, step=0.1524, count=[12718]),
#  'DPHI_LIM': Curve(mnemonic=DPHI_LIM, units=m3/m3, start=1.0668, stop=1939.1376, step=0.1524, count=[12718]),
#  'DPHI_DOL': Curve(mnemonic=DPHI_DOL, units=m3/m3, start=1.0668, stop=1939.1376, step=0.1524, count=[12718]),
#  'NPHI_SAN': Curve(mnemonic=NPHI_SAN, units=m3/m3, start=1.0668, stop=1939.1376, step=0.1524, count=[12718]),
#  'NPHI_LIM': Curve(mnemonic=NPHI_LIM, units=m3/m3, start=1.0668, stop=1939.1376, step=0.1524, count=[12718]),
#  'NPHI_DOL': Curve(mnemonic=NPHI_DOL, units=m3/m3, start=1.0668, stop=1939.1376, step=0.1524, count=[12718]),
#  'RLA5': Curve(mnemonic=RLA5, units=ohm.m, start=1.0668, stop=1939.1376, step=0.1524, count=[12718]),
#  'RLA3': Curve(mnemonic=RLA3, units=ohm.m, start=1.0668, stop=1939.1376, step=0.1524, count=[12718]),
#  'RLA4': Curve(mnemonic=RLA4, units=ohm.m, start=1.0668, stop=1939.1376, step=0.1524, count=[12718]),
#  'RLA1': Curve(mnemonic=RLA1, units=ohm.m, start=1.0668, stop=1939.1376, step=0.1524, count=[12718]),
#  'RLA2': Curve(mnemonic=RLA2, units=ohm.m, start=1.0668, stop=1939.1376, step=0.1524, count=[12718]),
#  'RXOZ': Curve(mnemonic=RXOZ, units=ohm.m, start=1.0668, stop=1939.1376, step=0.1524, count=[12718]),
#  'RXO_HRLT': Curve(mnemonic=RXO_HRLT, units=ohm.m, start=1.0668, stop=1939.1376, step=0.1524, count=[2139]),
#  'RT_HRLT': Curve(mnemonic=RT_HRLT, units=ohm.m, start=1.0668, stop=1939.1376, step=0.1524, count=[12718]),
#  'RM_HRLT': Curve(mnemonic=RM_HRLT, units=ohm.m, start=1.0668, stop=1939.1376, step=0.1524, count=[12718]),
#  'DRHO': Curve(mnemonic=DRHO, units=g/cm3, start=1.0668, stop=1939.1376, step=0.1524, count=[12718]),
#  'RHOB': Curve(mnemonic=RHOB, units=g/cm3, start=1.0668, stop=1939.1376, step=0.1524, count=[12707]),
#  'GR': Curve(mnemonic=GR, units=gAPI, start=1.0668, stop=1939.1376, step=0.1524, count=[12718]),
#  'SP': Curve(mnemonic=SP, units=mV, start=1.0668, stop=1939.1376, step=0.1524, count=[12718])}

# %% [markdown]
# ## Instantiating a new curve
#
# Let's add a curve from a list of values (`data`) with depths (`basis`):

# %%
from welly import Curve

# %%
params = {'mnemonic': 'FOO', 'run':0, }
data = [20, 30, 40, 20, 10, 0, 10]
c = Curve(data, index=[2,3,4,5,6,7,8], **params)

# %%
c.plot()
# Out:
# <Axes: title={'center': 'FOO'}>

# %% [markdown]
# ## Limit curves in depth

# %%
gr = w.data['GR']

gr
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:342: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if self.dtypes[0] == float:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:347: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rows += s.format(depth, value[0])
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:350: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rows += s.format(depth, value[0])
# Curve(mnemonic=GR, units=gAPI, start=1.0668, stop=1939.1376, step=0.1524, count=[12718])

# %%
gr.to_basis(start=1000, stop=1500)
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:342: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if self.dtypes[0] == float:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:347: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rows += s.format(depth, value[0])
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:350: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rows += s.format(depth, value[0])
# Curve(mnemonic=GR, units=gAPI, start=1000.0000, stop=1499.8720, step=0.1524, count=[3281])

# %% [markdown]
# We can do this to all the curves in a well — **this will overwrite all the curves; give them a new name if you don't want that to happen!**

# %%
for mnemonic, curve in w.data.items():
    w.data[mnemonic] = curve.to_basis(start=1000, stop=1500)
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:

# %% [markdown]
# Now save to a new LAS file:

# %%
w.to_las('data/P-129_1000-1500.las')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\las.py:423, in to_lasio(well, keys, alias, basis, null_value, mnemonic_case)
#     422 try:
# --> 423     l.add_curve('DEPT', df_merged.index.values)
#     424 except:
#
# AttributeError: 'LASFile' object has no attribute 'add_curve'
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 w.to_las('data/P-129_1000-1500.las')
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\well.py:540, in Well.to_las(self, fname, keys, basis, null_value, mnemonic_case, **kwargs)
#     520 """
#     521 Writes the current well instance as a LAS file. Essentially just wraps
#     522 ``to_lasio()``, but is more convenient for most purposes.
#    (...)
#     537     None. Writes the file as a side-effect.
#     538 """
#     539 with open(fname, 'w') as f:
# --> 540     las = self.to_lasio(keys=keys, basis=basis, null_value=null_value, mnemonic_case=mnemonic_case)
#     541     las.write(f, **kwargs)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\well.py:509, in Well.to_lasio(self, keys, alias, basis, null_value, mnemonic_case)
#     491 def to_lasio(self, keys=None, alias=None, basis=None, null_value=-999.25, mnemonic_case=None):
#     492     """
#     493     Makes a lasio object from the current well.
#     494
#    (...)
#     507         las (lasio.LASFile). The lasio object representation of a LAS file.
#     508     """
# --> 509     las = to_lasio(self, keys, alias, basis, null_value, mnemonic_case=mnemonic_case)
#     511     return las
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\las.py:425, in to_lasio(well, keys, alias, basis, null_value, mnemonic_case)
#     423     l.add_curve('DEPT', df_merged.index.values)
#     424 except:
# --> 425     raise Exception("Please provide an index.")
#     427 # Add meta from basis.
#     428 setattr(l.well, 'STRT', df_merged.index[0])
#
# Exception: Please provide an index.

# %%
# !head -10 P-129_1000-1500.las
# Out:
# 'head' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ## Another way to do it

# %%
# Reload the file so we have all the data as before.
w = Well.from_las('data/P-129_out.LAS')
# Out:
# Only engine='normal' can read wrapped files

# %%
# WARNING: This works in place and overwrites the logs.
w.unify_basis(start=1000, stop=1500)
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:

# %%
w.plot(tracks=['MD', 'CALI', 'GR', 'DT'])

# %% [markdown]
# ## Curve info

# %%
# Reload the file so we have all the data as before.
w = Well.from_las('data/P-129_out.LAS')
# Out:
# Only engine='normal' can read wrapped files

# %% [markdown]
# In Jupyter Notebook, the `__repr__()` is a little table summarizing the curve data...

# %%
gr = w.data['GR']
gr
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:342: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if self.dtypes[0] == float:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:347: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rows += s.format(depth, value[0])
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:350: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rows += s.format(depth, value[0])
# Curve(mnemonic=GR, units=gAPI, start=1.0668, stop=1939.1376, step=0.1524, count=[12718])

# %%
gr.read_at(168.7068)
# Out:
# np.float64(72.293632507)

# %%
gr.basis
# Out:
# array([1.0668000e+00, 1.2192000e+00, 1.3716000e+00, ..., 1.9388328e+03,
#        1.9389852e+03, 1.9391376e+03], shape=(12718,))

# %%
gr[1000:1010]
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:342: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if self.dtypes[0] == float:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:347: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rows += s.format(depth, value[0])
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:350: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rows += s.format(depth, value[0])
# Curve(mnemonic=GR, units=gAPI, start=1000.0488, stop=1009.9548, step=0.1524, count=[66])

# %% [markdown]
# `Curve` objects are just `ndarray`s, so we get lots of things for free...

# %%
gr.describe()  # Equivalent to get_stats()
# Out:
#                      GR
# count  12718.0000000000
# mean      78.9863535888
# std       37.0719153332
# min        3.8940699100
# 25%       51.3325605393
# 50%       76.5569686890
# 75%      109.8330020900
# max      267.9404296900

# %%
gr.get_stats()
# Out:
# {'samples': 12718,
#  'nulls': np.int64(0),
#  'mean': 78.9863535887685,
#  'min': 3.89406991,
#  'max': 267.94042969}

# %%
import numpy as np
m = np.mean(gr)

# %%
m  # Not really sure why this is a Curve
# Out:
# np.float64(78.9863535887685)

# %%
gr.mnemonic
# Out:
# 'GR'

# %%
w.data['GR_DESP'] = gr.despike(window_length=50, z=2)
w.plot(tracks = [['GR', 'GR_DESP']])
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:

# %% [markdown]
# ## Slicing
#
# It's usually better to get a subset of the data with `to_basis()` (see below, _Getting a segment of the data_). But you can slice with indices too:

# %%
gr.start, gr.stop
# Out:
# (np.float64(1.0668), np.float64(1939.1376))

# %%
g = gr[1000:1020]

# %%
g.basis
# Out:
# array([1000.0488, 1000.2012, 1000.3536, 1000.506 , 1000.6584, 1000.8108,
#        1000.9632, 1001.1156, 1001.268 , 1001.4204, 1001.5728, 1001.7252,
#        1001.8776, 1002.03  , 1002.1824, 1002.3348, 1002.4872, 1002.6396,
#        1002.792 , 1002.9444, 1003.0968, 1003.2492, 1003.4016, 1003.554 ,
#        1003.7064, 1003.8588, 1004.0112, 1004.1636, 1004.316 , 1004.4684,
#        1004.6208, 1004.7732, 1004.9256, 1005.078 , 1005.2304, 1005.3828,
#        1005.5352, 1005.6876, 1005.84  , 1005.9924, 1006.1448, 1006.2972,
#        1006.4496, 1006.602 , 1006.7544, 1006.9068, 1007.0592, 1007.2116,
#        1007.364 , 1007.5164, 1007.6688, 1007.8212, 1007.9736, 1008.126 ,
#        1008.2784, 1008.4308, 1008.5832, 1008.7356, 1008.888 , 1009.0404,
#        1009.1928, 1009.3452, 1009.4976, 1009.65  , 1009.8024, 1009.9548,
#        1010.1072, 1010.2596, 1010.412 , 1010.5644, 1010.7168, 1010.8692,
#        1011.0216, 1011.174 , 1011.3264, 1011.4788, 1011.6312, 1011.7836,
#        1011.936 , 1012.0884, 1012.2408, 1012.3932, 1012.5456, 1012.698 ,
#        1012.8504, 1013.0028, 1013.1552, 1013.3076, 1013.46  , 1013.6124,
#        1013.7648, 1013.9172, 1014.0696, 1014.222 , 1014.3744, 1014.5268,
#        1014.6792, 1014.8316, 1014.984 , 1015.1364, 1015.2888, 1015.4412,
#        1015.5936, 1015.746 , 1015.8984, 1016.0508, 1016.2032, 1016.3556,
#        1016.508 , 1016.6604, 1016.8128, 1016.9652, 1017.1176, 1017.27  ,
#        1017.4224, 1017.5748, 1017.7272, 1017.8796, 1018.032 , 1018.1844,
#        1018.3368, 1018.4892, 1018.6416, 1018.794 , 1018.9464, 1019.0988,
#        1019.2512, 1019.4036, 1019.556 , 1019.7084, 1019.8608])

# %% [markdown]
# Notice that the basis is updated to match the data retrieved by the slice.

# %% [markdown]
# ## Plotting and reading

# %%
gr.plot(lw=0.5)
# Out:
# <Axes: title={'center': 'GR'}, xlabel='gAPI'>

# %% [markdown]
# There's also an experimental 'imshow'-style 2D plot.

# %%
gr.plot_2d(cmap='viridis_r')
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
gr.plot_2d(cmap='viridis_r', curve=True, lw=0.3, edgecolor='k')
plt.xlim(0,200)
# Out:
# (0.0, 200.0)

# %% [markdown]
# ## Interpolated values
#
# You can get values from anywhere on the log:

# %%
gr.step
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# np.float64(0.1524000000000001)

# %%
gr.read_at(1001)
# Out:
# np.float64(97.99112340886289)

# %%
gr.read_at([1001, 1003, 1004])
# Out:
# [np.float64(97.99112340886289),
#  np.float64(116.81626549853009),
#  np.float64(104.14886540398906)]

# %% [markdown]
# ## Despike
#
# You can despike with a window length for the trend and a Z-score to clip at — the curve is compared to the median *in the window* using the standard deviation *from the entire curve*. Here's the difference:

# %%
w.data['DESP'] = gr.despike(z=1)
w.data['DIFF'] = gr - w.data['DESP']
w.plot(tracks=['GR', 'DESP', 'DIFF'])
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\welly\curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:

# %% [markdown]
# ## Changing basis
#
# You can easily upscale a bit by changing the step:

# %%
gr.to_basis(step=5).plot()
# Out:
# <Axes: title={'center': 'GR'}, xlabel='gAPI'>

# %% [markdown]
# Or take out a segment of the log:

# %%
newb = gr.to_basis(start=1207, stop=1215)
newb.plot()
# Out:
# <Axes: title={'center': 'GR'}, xlabel='gAPI'>

# %%
silly = newb.to_basis(start=1205, step=2)
silly.plot(marker='o')

# Curve starts at 1207 m (see above); does not extrapolate.
# Out:
# <Axes: title={'center': 'GR'}, xlabel='gAPI'>

# %%
dt = w.data['DT']
dt.to_basis_like(newb.basis).plot()
# Out:
# <Axes: title={'center': 'DT'}, xlabel='us/ft'>

# %% [markdown]
# ## Getting a segment of the data

# %%
segment = gr.to_basis(start=600, stop=680)

# %%
segment.basis[-1]
# Out:
# np.float64(679.8576)

# %%
fig, axs = plt.subplots(ncols=2)

segment.plot(ax=axs[0], c='r')
axs[0].axvline(80, c='c', alpha=0.7)
segment.block(cutoffs=80).plot(ax=axs[1])
axs[1].set_xlabel('')
# Out:
# Text(0.5, 0, '')

# %%
fig, ax = plt.subplots()

segment.plot(ax=ax)
segment.block(cutoffs=(80, 120), values=(20, 100, 150)).plot(ax=ax)
# Out:
# <Axes: title={'center': 'GR'}, xlabel='gAPI'>

# %% [markdown]
# You can use a cutoff of, say, 120 API, then reassign the output values to whatever you like:

# %%
segment.block(cutoffs=120, values=(2.718, 3.142)).plot()
# Out:
# <Axes: title={'center': 'GR'}, xlabel='gAPI'>

# %% [markdown]
# You can send a function in to determine replacement values from the original log. E.g., to replace the values with the block means:

# %%
fig, ax = plt.subplots()

segment.plot(ax=ax)
segment.block(cutoffs=80, function=np.mean).plot(ax=ax)
plt.axvline(80, color='c', lw=1)

# %% [markdown]
# ---
#
# &copy; 2022 Agile Scientific, CC BY
